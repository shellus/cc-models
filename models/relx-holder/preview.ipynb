# %% [markdown]
# # 悦刻5代烟弹底座

# %%
from jupyter_cadquery import show, open_viewer
open_viewer("cadquery")
# Out:
# Overwriting auto display for cadquery Workplane and Shape

# %%
# %run model.py
# Out:
# 模型已生成！
# 底座尺寸: 128.5 x 25.6 x 15.5 mm
# 凹槽尺寸: 18.5 x 9.6 mm
# 凹槽间距: 23.5 mm（中心到中心）
# 凹槽深度: 10 mm + 倒角 1.5 mm
# 底部厚度: 4 mm

# %%
show(result)
# Out:
# +

# %%
# %run model.py --export
