# %% [markdown]
# # 悦刻5代烟弹底座

# %%
from jupyter_cadquery import show, open_viewer
open_viewer("cadquery")

# %%
# %run model.py
# Out:
# 模型已生成！
# 底座尺寸: 91.7 x 23.7 x 12 mm
# 椭圆凹槽: 11.7 x 7.7 mm (间隙 +0.2 mm)
# 凹槽深度: 8 mm
# 顶部倒角: 1.5 mm（漏斗形引导）
# 已导出: model.step, model.stl

# %%
show(result)
# Out:
# +

# %%
import cadquery as cq
cq.exporters.export(result, "model.step")
cq.exporters.export(result, "model.stl")
print("已导出: model.step, model.stl")
